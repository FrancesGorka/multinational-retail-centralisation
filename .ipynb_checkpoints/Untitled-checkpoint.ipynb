# %%
import yaml
import pandas as pd
from sqlalchemy import create_engine, text

with open('db_creds.yaml', 'r') as f:
    yaml_data = yaml.safe_load(f)

# %%
credentials = yaml_data

RDS_HOST = credentials['RDS_HOST']
RDS_PASSWORD = credentials['RDS_PASSWORD']
RDS_USER = credentials['RDS_USER']
RDS_DATABASE = credentials['RDS_DATABASE']
RDS_PORT = credentials['RDS_PORT']

connection_string = f"postgresql+psycopg2://{RDS_USER}:{RDS_PASSWORD}@{RDS_HOST}:{RDS_PORT}/{RDS_DATABASE}"
engine = create_engine(connection_string)

# %%
with engine.connect() as connection:
    query = text("SELECT * FROM legacy_users LIMIT 100")
    result = connection.execute(query)

df = pd.DataFrame(result.fetchall(), columns=result.keys())

df
# Out:
#     index first_name last_name date_of_birth  \
# 0       0   Sigfried     Noack    1990-09-30
# 1       1        Guy     Allen    1940-12-01
# 2       2      Harry  Lawrence    1995-08-02
# 3       3     Darren   Hussain    1972-09-23
# 4       4      Garry     Stone    1952-12-20
# ..    ...        ...       ...           ...
# 95     95     Oliver     Jacob    1949-11-11
# 96     96     Vitali     Löwer    1955-12-29
# 97     97   Samantha     Patel    1976-03-11
# 98     98    Jasmine    Davies    1991-10-05
# 99     99       Dean     Booth    1981-10-23
#
#                              company                     email_address  \
# 0                 Heydrich Junitz KG                 rudi79@winkler.de
# 1                            Fox Ltd      rhodesclifford@henderson.com
# 2          Johnson, Jones and Harris      glen98@bryant-marshall.co.uk
# 3                        Wheeler LLC        daniellebryan@thompson.org
# ...

# %%
df['phone_number'] = df['phone_number'].str.replace(r'\D', '', regex=True)

# %%
df
# Out:
#     index first_name last_name date_of_birth  \
# 0       0   Sigfried     Noack    1990-09-30
# 1       1        Guy     Allen    1940-12-01
# 2       2      Harry  Lawrence    1995-08-02
# 3       3     Darren   Hussain    1972-09-23
# 4       4      Garry     Stone    1952-12-20
# ..    ...        ...       ...           ...
# 95     95     Oliver     Jacob    1949-11-11
# 96     96     Vitali     Löwer    1955-12-29
# 97     97   Samantha     Patel    1976-03-11
# 98     98    Jasmine    Davies    1991-10-05
# 99     99       Dean     Booth    1981-10-23
#
#                              company                     email_address  \
# 0                 Heydrich Junitz KG                 rudi79@winkler.de
# 1                            Fox Ltd      rhodesclifford@henderson.com
# 2          Johnson, Jones and Harris      glen98@bryant-marshall.co.uk
# 3                        Wheeler LLC        daniellebryan@thompson.org
# ...

# %%
x = [1,2,3]
2*x
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
import requests
import pandas as pd

def list_number_of_stores(endpoint, header_dict):
    # Returns the number of stores to extract
    response = requests.get(endpoint, headers=header_dict)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to fetch the number of stores")
        return 0

def retrieve_stores_data(endpoint, header_dict, no_of_stores):
    # Extracts all stores from API and saves to pandas dataframe
    store_data_list = []
    for store_number in range(1,no_of_stores+1):
        full_endpoint = endpoint.format(store_number = store_number)
        response = requests.get(full_endpoint,headers=header_dict)
        if response.status_code == 200:
            store_data = response.json()
            store_data_list.append(store_data)
        else:
            print(f"Failed to retrieve data for store {store_number}")
            store_data_list.append(0)
        stores_df = pd.DataFrame(store_data_list)
    return stores_dataframe

# %%
no_of_stores_endpoint = "https://aqj7u5id95.execute-api.eu-west-1.amazonaws.com/prod/number_stores"
store_retrieval_endpoint = "https://aqj7u5id95.execute-api.eu-west-1.amazonaws.com/prod/store_details/{store_number}"
header_dict = {'x-api-key': 'yFBQbwXe9J3sd6zWVAMrK6lcxxr0q1lr2PT6DDMX'}

no_of_stores = list_number_of_stores(no_of_stores_endpoint, header_dict)
#store_data = retrieve_stores_data(store_retrieval_endpoint, header_dict, no_of_stores['number_stores'])

# %%
full_endpoint = store_retrieval_endpoint.format(no_of_stores)
#response = requests.get(full_endpoint,headers=header_dict)
#response.json()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 store_retrieval_endpoint.format(no_of_stores)
#
# KeyError: 'store_number'

# %%
response = requests.get(full_endpoint,headers=header_dict)
        if response.status_code == 200:
            store_data = response.json()
            store_data_list.append(store_data)
        else:
            print(f"Failed to retrieve data for store {store_number}")
            store_data_list.append(0)
        stores_df = pd.DataFrame(store_data_list)
    return stores_dataframe
